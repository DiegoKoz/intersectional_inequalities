# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
from libs.LastNamesInference import LastNamesInference
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
us_papers = pd.read_csv('/data/datasets/WOS/US/US_papers.txt')

df_socsci = pd.read_csv('/data/datasets/WOS/US/text_clean_socsci.txt')
df_health = pd.read_csv('/data/datasets/WOS/US/text_clean_health.txt')

# %%
us_papers
# Out:
#           cluster_ID  Annee_Bibliographique   yfp    id_art      Prenom  \
# 0           13549990                   2008  2004  29883344     Vandana
# 1           13550014                   2018  2018  62789918       M. Q.
# 2           13550153                   2016  1998  57345792   Hannah L.
# 3           13550157                   2013  2007  50662363  Heather L.
# 4           13550157                   2014  2007  54149898  Heather L.
# ...              ...                    ...   ...       ...         ...
# 21295328    55572281                   2015  1979  54484094     P. Ewen
# 21295329    55572281                   2010  1979  63796210       P. E.
# 21295330    55572321                   2016  2014  57035670       K. D.
# 21295331    55572321                   2016  2014  61863266        Kyla
# 21295332    55572373                   2015  2015  53824626        Umut
#
#                    nom  ordre  nb_auteur                 EDiscipline  \
# 0             Hirani-V      3          5         Biomedical Research
# 1           Salzano-MQ      2          4                     Biology
# 2           Buckley-HL      4          7                     Biology
# 3           Buckley-HL      1          4                   Chemistry
# 4           Buckley-HL      1          6                   Chemistry
# ...                ...    ...        ...                         ...
# 21295328  KingSmith-PE      1          2           Clinical Medicine
# 21295329  KingSmith-PE      2          2           Clinical Medicine
# 21295330     Driest-KD      1          6           Clinical Medicine
# 21295331      Driest-K      2          3           Clinical Medicine
# 21295332      Arslan-U      2         12  Engineering and Technology
#
#                                    ESpecialite  cit_rel_all_IAC  ordre_auteur  \
# 0             Biochemistry & Molecular Biology            0.584             3
# 1                              General Zoology              NaN             2
# 2                                      Ecology            2.736             4
# 3                            General Chemistry            0.351             1
# 4                            General Chemistry              NaN             1
# ...                                        ...              ...           ...
# 21295328                         Ophthalmology              NaN             1
# 21295329                         Ophthalmology              NaN             2
# 21295330              Arthritis & Rheumatology            0.355             1
# 21295331              Arthritis & Rheumatology              NaN             2
# 21295332  Electrical Engineering & Electronics            0.282             2
#
#          Province                 disc_origin  \
# 0              NJ           Clinical Medicine
# 1              PA                     Biology
# 2              MA                     Biology
# 3              CA                   Chemistry
# 4              CA                   Chemistry
# ...           ...                         ...
# 21295328       OH           Clinical Medicine
# 21295329       OH           Clinical Medicine
# 21295330       OH           Clinical Medicine
# 21295331       OH           Clinical Medicine
# 21295332       OR  Engineering and Technology
#
#                                    spec_origin   count_origin gender  \
# 0                                 Pharmacology            NaN      F
# 1                              General Zoology  United States    INI
# 2                                       Botany            NaN      F
# 3                            Organic Chemistry            NaN      F
# 4                            Organic Chemistry            NaN      F
# ...                                        ...            ...    ...
# 21295328              Neurology & Neurosurgery            NaN      M
# 21295329              Neurology & Neurosurgery            NaN    INI
# 21295330              Arthritis & Rheumatology  United States    INI
# 21295331              Arthritis & Rheumatology  United States      F
# 21295332  Electrical Engineering & Electronics  United States      M
#
#           cit_all_IAC
# 0                24.0
# 1                 NaN
# 2                20.0
# 3                 9.0
# 4                 NaN
# ...               ...
# 21295328          NaN
# 21295329          NaN
# 21295330          3.0
# 21295331          NaN
# 21295332          2.0
#
# [21295333 rows x 18 columns]

# %% [markdown]
# Number of articles

# %%
us_papers.Annee_Bibliographique.agg({min,max})
# Out:
# max    2019
# min    2008
# Name: Annee_Bibliographique, dtype: int64

# %%
len(us_papers.id_art.unique())
# Out:
# 5431451

# %% [markdown]
# Number of Auuthors:

# %%
len(us_papers.cluster_ID.unique())
# Out:
# 4713444

# %%
len(df_socsci.id_art.unique())
# Out:
# 283589

# %%
len(df_health.id_art.unique())
# Out:
# 142032
